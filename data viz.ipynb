# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
from pandas import *

# %%
#import dataset file
data = read_excel('WHO POP TB some.xls')
data
# Out:
#                   Country  Population (1000s)  TB deaths
# 0                  Angola               21472       6900
# 1                  Brazil              200362       4400
# 2                   China             1393337      41000
# 3       Equatorial Guinea                 757         67
# 4           Guinea-Bissau                1704       1200
# 5                   India             1252140     240000
# 6              Mozambique               25834      18000
# 7                Portugal               10608        140
# 8      Russian Federation              142834      17000
# 9   Sao Tome and Principe                 193         18
# 10           South Africa               52776      25000
# 11            Timor-Leste                1133        990

# %%
#Rename column
data.rename(columns = {'Population (1000s)': 'Pop'})
# Out:
#                   Country      Pop  TB deaths
# 0                  Angola    21472       6900
# 1                  Brazil   200362       4400
# 2                   China  1393337      41000
# 3       Equatorial Guinea      757         67
# 4           Guinea-Bissau     1704       1200
# 5                   India  1252140     240000
# 6              Mozambique    25834      18000
# 7                Portugal    10608        140
# 8      Russian Federation   142834      17000
# 9   Sao Tome and Principe      193         18
# 10           South Africa    52776      25000
# 11            Timor-Leste     1133        990

# %%
avg_by_country = data.groupby(by = 'Country').mean()
avg_by_country
# Out:
#                        Population (1000s)  TB deaths
# Country
# Angola                              21472       6900
# Brazil                             200362       4400
# China                             1393337      41000
# Equatorial Guinea                     757         67
# Guinea-Bissau                        1704       1200
# India                             1252140     240000
# Mozambique                          25834      18000
# Portugal                            10608        140
# Russian Federation                 142834      17000
# Sao Tome and Principe                 193         18
# South Africa                        52776      25000
# Timor-Leste                          1133        990

# %%
data.rename(columns = {'Population (1000s)': 'Pop'})
# Out:
#                   Country      Pop  TB deaths
# 0                  Angola    21472       6900
# 1                  Brazil   200362       4400
# 2                   China  1393337      41000
# 3       Equatorial Guinea      757         67
# 4           Guinea-Bissau     1704       1200
# 5                   India  1252140     240000
# 6              Mozambique    25834      18000
# 7                Portugal    10608        140
# 8      Russian Federation   142834      17000
# 9   Sao Tome and Principe      193         18
# 10           South Africa    52776      25000
# 11            Timor-Leste     1133        990

# %%
avg_by_country.Pop.plot(kind = 'bar')

plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-39-748a71180ab3> in <module>
# ----> 1 avg_by_country.Pop.plot(kind = 'bar')
#       2
#       3 plt.show()
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5272             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5273                 return self[name]
# -> 5274             return object.__getattribute__(self, name)
#    5275
#    5276     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'Pop'

# %%
data.Country.unique()

# %%
TB_Deaths.Pop.plot(kind = 'bar')

plt.show()

# %%
pop_by_region = data[['Country', 'Pop']]

pop_by_region

# %%
Country.plot.pie('Pop', 
                       figsize = (8, 8))

plt.show()
